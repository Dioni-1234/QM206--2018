# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Cinética de primer orden
# ## A --> B

# %%
A=1.0
B=0
k1=0.1
dt=0.1
t=0
x=[]
yA=[]
yB=[]
while t<100:
    x.append(t)
    yA.append(A)
    yB.append(B)
    dA=-k1*A*dt
    dB=+k1*A*dt
    A+=dA
    B+=dB
    t+=dt
plt.plot(x,yA)
plt.plot(x,yB)
plt.xlabel('Tiempo(min)')
plt.ylabel('Concentación')
plt.title('Cinetica de primer orden')
plt.show()

# %% [markdown]
# ## Cinética secuencial
# ## A--> B
# ## B--> C

# %%
A=1.0
B=0
C=0
k1=0.1
k2=0.11
dt=0.1
t=0
x=[]
yA=[]
yB=[]
yC=[]
while t<100:
    x.append(t)
    yA.append(A)
    yB.append(B)
    yC.append(C)
    dA=-k1*A*dt
    dB=-k2*B*dt+k1*A*dt
    dC=+k2*B*dt
    A+=dA
    B+=dB
    C+=dC
    t+=dt
plt.plot(x,yA)
plt.plot(x,yB)
plt.plot(x,yC)
plt.xlabel('Tiempo(min)')
plt.ylabel('Concentación')
plt.title('Cinetica de segundo orden')
plt.show()

# %% [markdown]
# ## Equilibrio químico de primer orden

# %%
A=1.0
B=0
k1=0.1
k2=0.2
dt=0.1
t=0
x=[]
yA=[]
yB=[]
while t<100:
    x.append(t)
    yA.append(A)
    yB.append(B)
    dA=-k1*A*dt+k2*B*dt
    dB=+k1*A*dt-k2*B*dt
    A+=dA
    B+=dB
    t+=dt
plt.plot(x,yA)
plt.plot(x,yB)
plt.xlabel('Tiempo(min)')
plt.ylabel('Concentación')
plt.title('Equilibrio químico')
plt.show()

# %% [markdown]
# ## Equilibrio de reacción de segundo orden

# %%
A=1.0
B=0
k1=0.1
dt=0.01
t=0
x=[]
yA=[]
yB=[]
while t<100:
    x.append(t)orden
    yA.append(A)
    yB.append(B)
    dA=-k1*A*A*dt
    dB=+k1*A*A*dt
    A+=dA
    B+=dB
    t+=dt
plt.plot(x,yA)
plt.plot(x,yB)
plt.xlabel('Tiempo(min)')
plt.ylabel('Concentación')
plt.title('Equilibrio de segundo orden')
plt.show()
